# %%
# !pip install -q -U google-generativeai
# Out:
# WARNING: Ignoring invalid distribution ~penai (C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: C:\Users\suraj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from google import genai

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

if not GEMINI_API_KEY:
    raise ValueError("GEMINI_API_KEY not found in .env file")

client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works"
)

print(response.text)
# Out:
# At its core, **Artificial Intelligence (AI)** works by enabling machines to learn, reason, and solve problems in ways that mimic human cognitive functions. It's not magic, but a combination of advanced mathematics, statistics, computer science, and engineering.
#
# Here's a breakdown of how AI generally works, moving from broad concepts to specific techniques:
#
# ---
#
# ### The Fundamental Idea: Learning from Data
#
# Imagine teaching a child. You show them many examples (e.g., pictures of cats and dogs) and tell them which is which. Eventually, the child learns to distinguish between cats and dogs on their own, even with new pictures.
#
# AI works similarly. Instead of a child, we have a computer program, and instead of a human teacher, we provide vast amounts of **data**.
#
# **The core steps usually involve:**
#
# 1.  **Data Collection & Preparation:** Gathering huge datasets relevant to the problem AI is trying to solve (images, text, numbers, sounds, etc.). This data must be cleaned, formatted, and often "labeled" (e.g., "this is a cat," "this email is spam").
# 2.  **Algorithm Selection:** Choosing the right mathematical model or "recipe" (algorithm) that will learn from the data.
# 3.  **Training:** Feeding the prepared data to the algorithm. During training, the algorithm adjusts its internal parameters (like knobs on a complex machine) to find patterns, relationships, and rules within the data. It tries to minimize errors in its predictions or classifications.
# 4.  **Model Creation:** The result of the training process is an "AI model." This model has learned from the data and is now capable of making predictions, classifications, or decisions on new, unseen data.
# 5.  **Inference/Prediction:** Using the trained model to process new information and generate an output. For example, showing a trained image recognition model a new picture and asking if it contains a cat.
# 6.  **Evaluation & Refinement:** Assessing how well the model performs and making adjustments or retraining with more data if necessary.
#
# ---
#
# ### Key AI Paradigms (How AI "Learns")
#
# Most modern AI relies heavily on **Machine Learning (ML)**, which is a subset of AI. **Deep Learning (DL)** is a further subset of ML.
#
# #### 1. Rule-Based AI (Early AI / Symbolic AI)
#
# *   **How it works:** Programmers explicitly define a set of "if-then" rules that the AI follows. The AI doesn't "learn" in the modern sense; it executes pre-programmed instructions.
# *   **Analogy:** A flowchart or a detailed instruction manual.
# *   **Examples:** Early expert systems (e.g., medical diagnostic systems with predefined symptoms and diseases), simple chatbots that follow scripts.
# *   **Limitations:** Becomes incredibly complex and brittle for problems with many variables or ambiguity. Doesn't adapt well to new situations.
#
# #### 2. Machine Learning (ML)
#
# This is the dominant approach today. Instead of explicit rules, ML algorithms learn patterns directly from data.
#
# ##### a. Supervised Learning
#
# *   **How it works:** The AI is trained on a dataset where each input is "labeled" with the correct output. It learns to map inputs to outputs.
# *   **Analogy:** A student given many practice problems with their correct answers, learning to solve similar problems on their own.
# *   **Types:**
#     *   **Classification:** Predicting a category (e.g., "Is this email spam or not spam?", "What type of animal is in this image?").
#     *   **Regression:** Predicting a continuous value (e.g., "What will the temperature be tomorrow?", "What will the price of this house be?").
# *   **Algorithms:** Linear Regression, Logistic Regression, Support Vector Machines (SVMs), Decision Trees, Random Forests.
# *   **Examples:** Spam detection, image recognition, predicting stock prices, medical diagnosis based on symptoms.
#
# ##### b. Unsupervised Learning
#
# *   **How it works:** The AI is given unlabeled data and told to find hidden patterns, structures, or relationships within it.
# *   **Analogy:** A child exploring a box of toys and grouping them by shape or color without being told what the groups are.
# *   **Types:**
#     *   **Clustering:** Grouping similar data points together (e.g., customer segmentation for marketing).
#     *   **Dimensionality Reduction:** Simplifying complex data by reducing the number of variables while retaining important information.
#     *   **Association:** Finding rules that describe relationships between items (e.g., "people who buy X also tend to buy Y").
# *   **Algorithms:** K-Means Clustering, Principal Component Analysis (PCA).
# *   **Examples:** Customer segmentation, anomaly detection (fraud detection), organizing large document archives.
#
# ##### c. Reinforcement Learning (RL)
#
# *   **How it works:** The AI (an "agent") learns by interacting with an environment, performing actions, and receiving rewards or penalties based on its actions. It tries to maximize its cumulative reward over time through trial and error.
# *   **Analogy:** Teaching a dog tricks with treats (rewards) and scolding (penalties).
# *   **Algorithms:** Q-learning, Policy Gradients.
# *   **Examples:** Training AI to play games (e.g., AlphaGo, chess), robotics (teaching robots to walk or grasp objects), self-driving cars (learning optimal driving strategies).
#
# #### 3. Deep Learning (DL)
#
# *   **How it works:** A specialized subset of Machine Learning that uses **Artificial Neural Networks (ANNs)** with many layers (hence "deep"). These networks are loosely inspired by the structure of the human brain. Each "neuron" in a layer takes inputs, performs a simple calculation, and passes the output to neurons in the next layer. The "deep" aspect refers to having multiple hidden layers between the input and output.
# *   **Analogy:** Instead of a single student, a network of many students (neurons) collaborating, each specializing in a tiny part of the problem, passing their findings to others.
# *   **Key Advantage:** Excellent at automatically extracting complex features from raw, unstructured data (like images, audio, text) without explicit programming.
# *   **How they learn:** Through a process called **backpropagation**, the network adjusts the "weights" (strength of connections between neurons) and "biases" in each layer based on how far its output was from the correct answer, gradually improving its accuracy. This requires massive amounts of data and computational power (often GPUs).
# *   **Types of Deep Learning Networks:**
#     *   **Convolutional Neural Networks (CNNs):** Ideal for image and video processing (e.g., facial recognition, object detection).
#     *   **Recurrent Neural Networks (RNNs):** Good for sequential data like text and speech (e.g., language translation, chatbots, speech recognition).
#     *   **Transformers:** A more recent and powerful architecture, especially for Natural Language Processing (NLP) tasks (e.g., large language models like GPT-3/4).
# *   **Examples:** Facial recognition, natural language processing (understanding and generating human language), voice assistants (Siri, Alexa), medical image analysis, drug discovery.
#
# ---
#
# ### In Summary:
#
# AI works by turning complex problems into mathematical ones. It uses **data** as fuel, **algorithms** as recipes, and **computation** as the engine to build **models** that can learn patterns, make predictions, and adapt. While rule-based AI simply follows instructions, modern AI (especially Machine Learning and Deep Learning) actually learns from experience (data) to perform tasks that once required human intelligence.

# %%
# !pip install -U phidata
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: phidata in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.7.10)
# Requirement already satisfied: docstring-parser in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (0.18.0)
# Requirement already satisfied: gitpython in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (3.1.46)
# Requirement already satisfied: httpx in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (2.12.5)
# Requirement already satisfied: pydantic-settings in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (2.15.0)
# Requirement already satisfied: python-dotenv in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (1.2.2)
# Requirement already satisfied: pyyaml in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (6.0.3)
# Requirement already satisfied: rich in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (14.3.3)
# Requirement already satisfied: tomli in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (2.4.1)
# Requirement already satisfied: typer in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (0.24.1)
# Requirement already satisfied: typing-extensions in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from phidata) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.3)
# Requirement already satisfied: anyio in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx->phidata) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx->phidata) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx->phidata) (1.0.9)
# Requirement already satisfied: idna in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx->phidata) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx->phidata) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic->phidata) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic->phidata) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich->phidata) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich->phidata) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: click>=8.2.1 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer->phidata) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer->phidata) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer->phidata) (0.0.4)
# Requirement already satisfied: colorama in C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from click>=8.2.1->typer->phidata) (0.4.6)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\suraj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: C:\Users\suraj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from google import genai

client = genai.Client(api_key=GEMINI_API_KEY)

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
# models/gemini-robotics-er-2-streaming-preview
# models/gemini-3.5-live-translate-preview

# %%
from phi.agent import Agent, RunResponse
from phi.model.google import Gemini
import os

# Set Google API key
os.environ["GOOGLE_API_KEY"] = ""

# Initialize the agent with Gemini
agent = Agent(
    model=Gemini(id="gemini-2.5-flash"),
    markdown=True,
)

# Get the response
run: RunResponse = agent.run(
    "Can you please book the hotel for me for 2 days? from OYO"
)

# Print the response
print(run.content)
# Out:
# I understand you'd like me to book a hotel for you for 2 days from OYO!
#
# Unfortunately, as an AI, I **cannot directly book hotels or make real-world transactions** for you. I don't have access to personal information like your name, payment details, or the ability to interact with booking systems like OYO's.
#
# However, I can certainly **help you find the perfect OYO hotel** and guide you through the process of booking it yourself!
#
# To do that, I'll need a little more information from you:
#
# 1.  **What city or specific location** are you planning to stay in?
# 2.  **What are your exact check-in and check-out dates?** (Even if it's 2 days, I need to know *which* two days.)
# 3.  **How many guests** will be staying (adults and children, if any)?
# 4.  **Do you have any specific preferences** (e.g., budget range, amenities like Wi-Fi or AC, a particular type of OYO property like OYO Rooms, OYO Townhouse, etc.)?
#
# Once I have these details, I can:
# *   Help you search for available OYO hotels in your desired location and dates.
# *   Provide direct links to the OYO website for you to complete your booking.
# *   Suggest specific OYO properties based on your preferences.
#
# Please provide the details, and I'll do my best to assist you!
